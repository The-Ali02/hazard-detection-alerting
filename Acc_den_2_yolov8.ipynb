# %%
# !nvidia-smi
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# Sun Apr  7 10:00:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/

# %%
# %cd /content/drive/MyDrive/Accident Detection model

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=10 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/Accident Detection model
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=val model=runs/detect/train8/weights/best.pt data=data.yaml
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-07 10:35:54.022001: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 10:35:54.022050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 10:35:54.023259: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 10:35:55.148090: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt conf=0.48 source=data/test/images save=True
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-07 10:36:23.383695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 10:36:23.383750: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 10:36:23.384885: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 10:36:24.835970: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt source="/content/drive/MyDrive/Accident Detection model/data/testing1.jpg"
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-05 21:40:59.671827: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 21:40:59.671875: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 21:40:59.673077: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-05 21:41:00.750915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# %cd {home}
# !yolo task=detect mode=predict model={home}runs/detect/train3/weights/best.pt source="/content/drive/MyDrive/Accident Detection model/data/testing1.jpg" -thresh 0.01 | grep "ACCIDENT" && echo "Accident is present" || echo "No accident detected"

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt conf = 0.48 source="/content/drive/MyDrive/Accident Detection model/data/video2.mp4" save = True
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-07 10:37:14.479616: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 10:37:14.479660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 10:37:14.480813: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 10:37:15.561907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt conf = 0.45 source="/content/drive/MyDrive/Accident Detection model/data/testing2.mp4" save = True
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-07 10:37:59.519729: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 10:37:59.519780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 10:37:59.521086: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 10:38:00.625506: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# %cd /content/drive/MyDrive/Accident Detection model
# !yolo task=detect mode=predict model=runs/detect/train8/weights/best.pt conf = 0.45 source="/content/drive/MyDrive/Accident Detection model/data/testing.mp4" save = True
# Out:
# /content/drive/MyDrive/Accident Detection model
# 2024-04-07 10:39:36.814888: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 10:39:36.814946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 10:39:36.816242: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 10:39:37.874449: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# import cv2

# import torch
# import cv2

# def detect_objects(image, model_path, conf_thres=0.4):
#     # Load the model
#     net = cv2.dnn.readNet(model_path)

#     # Get the names of the output layers
#     layer_names = net.getLayerNames()
#     output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

#     # Resize the image and normalize pixel values to [0, 1]
#     blob = cv2.dnn.blobFromImage(image, 1/255, (416, 416), swapRB=True, crop=False)

#     # Set the input of the network
#     net.setInput(blob)

#     # Forward pass through the network
#     outputs = net.forward(output_layers)

#     # Parse the outputs and get the class IDs, confidences and bounding boxes
#     class_ids, confidences, boxes = [], [], []
#     for output in outputs:
#         for detection in output:
#             scores = detection[5:]
#             class_id = np.argmax(scores)
#             confidence = scores[class_id]
#             if confidence > conf_thres:
#                 center_x, center_y, width, height = detection[:4] * np.array([image.shape[1], image.shape[0], image.shape[1], image.shape[0]])
#                 x, y = int(center_x - width/2), int(center_y - height/2)
#                 w, h = int(width), int(height)
#                 class_ids.append(class_id)
#                 confidences.append(float(confidence))
#                 boxes.append([x, y, w, h])

#     # Return the class IDs, confidences and bounding boxes
#     return class_ids, confidences, boxes


# # Load the output image
# output_image = cv2.imread("/content/drive/MyDrive/Accident Detection model/runs/detect/predict2/testing1.jpg")

# # Set the path to your YOLO model
# model_path = "/content/drive/MyDrive/Accident Detection model/runs/detect/train2/weights/best.pt"

# # Get the number of objects detected
# num_objects = len(detect_objects(output_image, model_path))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-03217fdbf037> in <cell line: 49>()
#      47
#      48 # Get the number of objects detected
# ---> 49 num_objects = len(detect_objects(output_image, model_path))
#      50
#      51 # Set a threshold for the number of objects
#
# <ipython-input-16-03217fdbf037> in detect_objects(image, model_path, conf_thres)
#       6 def detect_objects(image, model_path, conf_thres=0.4):
#       7     # Load the model
# ----> 8     net = cv2.dnn.readNet(model_path)
#       9
#      10     # Get the names of the output layers
#
# error: OpenCV(4.8.0) /io/opencv/modules/dnn/src/dnn_read.cpp:56: error: (-2:Unspecified error) Cannot determine an origin framework of files: /content/drive/MyDrive/Accident Detection model/runs/detect/train2/weights/best.pt in function 'readNet'
